# %%
# Run this every time you open the spreadsheet
# %load_ext autoreload
# %autoreload 2
from collections import Counter
import lib

# %% [markdown]
# # Load and inspect the data

# %%
# Load the data.
tweets, test_tweets = lib.read_data(train_path="data/labeled-data-singlelabels-train.csv", 
                                    test_path="data/labeled-data-singlelabels-test.csv")

# This function prints out a table containing all the tweets, along with their category labels
lib.show_tweets(tweets)
# Out:
# <style  type="text/css" >
#     #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow0_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow0_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow1_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow1_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow2_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow2_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow3_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow3_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow4_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow4_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow5_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow5_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow6_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow6_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow7_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow7_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow8_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow8_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow9_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow9_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow10_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow10_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow11_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow11_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow12_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow12_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow13_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow13_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow14_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow14_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow15_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow15_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow16_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow16_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow17_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow17_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow18_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow18_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow19_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow19_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow20_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow20_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_378e2ede_5902_11e9_aaf3_8c8590508d6crow21_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_378e2ede_

# %% [markdown]
# # Naive Bayes classifier
#
# To construct our Naive Bayes classifier, we first need to calculate two things:
#
# ### Prior probabilities of categories
# We need to calculate $P(C_i)$ for each category $C_i \in \{\text{Energy}, \text{Food}, \text{Medical}, \text{Water}, \text{None}\}$.
#
# We estimate $P(C_i)$ by $\frac{\text{# tweets about }C_i}{\text{# tweets}}$
#
# ### Conditional probabilities of tokens
# For each token (i.e. word) $x_j$ and each category $C_i$, we need to calculate $P(x_j|C_i)$.
#
# We estimate $P(x_j|C_i) = \frac{P(x_j \text{ and } C_i)}{P(C_i)}$ by $\frac{\text{# tweets about }C_i \text{ containing }x_j}{\text{# tweets about }C_i}$
#
# ### Posterior probability of categories
# Given a tweet which is a set of tokens $\{x_1,...,x_n\}$, the posterior probability of each category $C_i$ is
#
# $P(C_i | x_1,...,x_n) \propto P(C_i) \times P(x_1|C_i) \times P(x_2|C_i) ... \times P(x_n|C_i)$
#
# ### Discriminator for choosing the output

# %%
def calc_probs(tweets, c):
    """
    Input:
        tweets: a list of tweets
        c: a string representing a category; one of "Energy", "Food", "Medical", "Water", "None". 
    Returns:
        prob_c: the prior probability of category c
        token_probs: a Counter mapping each token to P(token|category c)
    """

    # Step 1: Calculate the total number of tweets
    num_tweets = len(tweets)

    # Step 2: Calculate the number of tweets that are about category c.
    num_tweets_about_c = len([t for t in tweets if t.category == c])

    # Step 3: Calculate the probability of category c using the answers from Steps 1 and 2.
    prob_c = float(num_tweets_about_c) / num_tweets

    # Step 4: Create an empty Counter called token_counts.
    token_counts = Counter()

    # Step 5 (tricky): Use a for-loop to iterate over the list of tweets.
    for tweet in tweets:
        if tweet.category == c:
            for token in tweet.tokenSet:
                token_counts[token] += 1

    # Step 6: Create an empty Counter called token_probs.
    token_probs = Counter()

    # Step 7: Now fill token_probs.
    for token, count in token_counts.items():
        token_probs[token] = float(count) / num_tweets_about_c

    print("Class %s has prior probability %.2f" % (c, prob_c))
    return prob_c, token_probs


def get_posterior_prob(tweet, prob_c, token_probs):
    """Calculate the posterior P(c|tweet). 
    (Actually, calculate something proportional to it).
    
    Inputs:
        tweet: a tweet
        prob_c: the prior probability of category c
        token_probs: a Counter mapping each token P(token|c)
    Return:
        The posterior P(c|tweet).
    """

    posterior = prob_c
    for token in tweet.tokenSet:
        if token_probs[token] == 0:
            posterior *= 0.001
        else:
            posterior *= token_probs[token]

    return posterior

def classify_nb(tweet):
    """Classifies a tweet. Calculates the posterior P(c|tweet) for each category c, 
    and returns the category with largest posterior.
    Input:
        tweet
    Output:
        string equal to most-likely category for this tweet
    """
    posterior_food_prob = get_posterior_prob(tweet, prob_food, token_probs_food)
    posterior_water_prob = get_posterior_prob(tweet, prob_water, token_probs_water)
    posterior_energy_prob = get_posterior_prob(tweet, prob_energy, token_probs_energy)
    posterior_medical_prob = get_posterior_prob(tweet, prob_medical, token_probs_medical)
    posterior_none_prob = get_posterior_prob(tweet, prob_none, token_probs_none)

    max_posterior = max(
        [posterior_food_prob, posterior_water_prob, posterior_energy_prob,
         posterior_medical_prob, posterior_none_prob]
    )
    if posterior_food_prob == max_posterior:
        return 'Food'
    elif posterior_water_prob == max_posterior:
        return 'Water'
    elif posterior_energy_prob == max_posterior:
        return 'Energy'
    elif posterior_medical_prob == max_posterior:
        return 'Medical'
    else:
        return 'None'

# %%
prob_food, token_probs_food = calc_probs(tweets, "Food")
prob_water, token_probs_water = calc_probs(tweets, "Water")
prob_energy, token_probs_energy = calc_probs(tweets, "Energy")
prob_medical, token_probs_medical = calc_probs(tweets, "Medical")
prob_none, token_probs_none = calc_probs(tweets, "None")
# Out:
# Class Food has prior probability 0.47
# Class Water has prior probability 0.09
# Class Energy has prior probability 0.12
# Class Medical has prior probability 0.04
# Class None has prior probability 0.28

# %% [markdown]
# ## Evaluate the Naive Bayes classifier

# %%
# Compare true labels and predicted labels in a table

predictions = [(tweet, classify_nb(tweet)) for tweet in test_tweets]  # a list of (tweet, prediction) pairs
lib.show_predictions(predictions)
# Out:
# <style  type="text/css" >
#     #T_edc80848_5905_11e9_aaf3_8c8590508d6crow0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow0_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow0_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow1_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow1_col2 {
#             color:  red;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow2_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow2_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow3_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow3_col2 {
#             color:  green;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow4_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow4_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow5_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow5_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow6_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow6_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow7_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow7_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow8_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow8_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow9_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow9_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow10_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow10_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow11_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow11_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow12_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow12_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow13_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow13_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow14_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow14_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow15_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow15_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow16_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow16_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow17_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow17_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow18_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow18_col2 {
#             color:  blue;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow19_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow19_col2 {
#             color:  red;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow20_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow20_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_edc80848_5905_11e9_aaf3_8c8590508d6crow21_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T

# %%
# Get average F1 score for the test set

predictions = [(tweet, classify_nb(tweet)) for tweet in test_tweets]  # maps each test tweet to its predicted label
lib.evaluate(predictions)
# Out:
# Energy
# Precision:  50.0
# Recall:  60.0
# F1:  54.54545454545455
#
# Food
# Precision:  83.56164383561644
# Recall:  94.57364341085271
# F1:  88.72727272727272
#
# Medical
# Precision:  85.71428571428571
# Recall:  46.15384615384615
# F1:  60.0
#
# None
# Precision:  82.85714285714286
# Recall:  73.41772151898734
# F1:  77.85234899328859
#
# Water
# Precision:  80.0
# Recall:  40.0
# F1:  53.333333333333336
#
# Average F1:  66.89168191986984

# %%
# Get average F1 score for the TRAINING set.
# Compare with average F1 for test set above. What's the reason for the difference?

trainset_predictions = [(tweet, classify_nb(tweet)) for tweet in
                        tweets]  # maps each training tweet to its predicted label
lib.evaluate(trainset_predictions)
# Out:
# Energy
# Precision:  95.77464788732394
# Recall:  98.55072463768116
# F1:  97.14285714285714
#
# Food
# Precision:  98.09885931558935
# Recall:  97.72727272727273
# F1:  97.91271347248579
#
# Medical
# Precision:  95.65217391304348
# Recall:  100.0
# F1:  97.77777777777777
#
# None
# Precision:  96.44012944983818
# Recall:  96.44012944983818
# F1:  96.44012944983818
#
# Water
# Precision:  100.0
# Recall:  96.03960396039604
# F1:  97.97979797979797
#
# Average F1:  97.45065516455136

# %%
lib.show_confusion_matrix(predictions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energy</th>
#       <th>Food</th>
#       <th>Medical</th>
#       <th>None</th>
#       <th>Water</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Energy</th>
#       <td>24</td>
#       <td>8</td>
#       <td>0</td>
#       <td>7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Food</th>
#       <td>2</td>
#       <td>122</td>
#       <td>0</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Medical</th>
#       <td>3</td>
#       <td>4</td>
#       <td>6</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>None</th>
#       <td>18</td>
#       <td>2</td>
#       <td>1</td>
#       <td>58</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Water</th>
#       <td>1</td>
#       <td>10</td>
#       <td>0</td>
#       <td>1</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>

# %%
tweets, test_tweets = lib.read_data()
prior_probs, token_probs = lib.learn_nb(tweets)
predictions = [(tweet, lib.classify_nb(tweet, prior_probs, token_probs)) for tweet in test_tweets]
lib.evaluate(predictions)
# Out:
# Energy
# Precision:  62.16216216216216
# Recall:  57.5
# F1:  59.74025974025974
#
# Food
# Precision:  85.0
# Recall:  92.24806201550388
# F1:  88.47583643122677
#
# Medical
# Precision:  75.0
# Recall:  46.15384615384615
# F1:  57.14285714285714
#
# None
# Precision:  79.01234567901234
# Recall:  81.0126582278481
# F1:  80.00000000000001
#
# Water
# Precision:  73.33333333333333
# Recall:  55.0
# F1:  62.85714285714286
#
# Average F1:  69.64321923429729

# %%
lib.show_confusion_matrix(predictions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energy</th>
#       <th>Food</th>
#       <th>Medical</th>
#       <th>None</th>
#       <th>Water</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Energy</th>
#       <td>23</td>
#       <td>10</td>
#       <td>0</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Food</th>
#       <td>3</td>
#       <td>118</td>
#       <td>1</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Medical</th>
#       <td>2</td>
#       <td>5</td>
#       <td>6</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>None</th>
#       <td>16</td>
#       <td>2</td>
#       <td>1</td>
#       <td>60</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Water</th>
#       <td>1</td>
#       <td>8</td>
#       <td>0</td>
#       <td>1</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions_train = [(tweet, lib.classify_nb(tweet, prior_probs, token_probs)) for tweet in tweets]
lib.evaluate(predictions_train)
# Out:
# Energy
# Precision:  95.83333333333333
# Recall:  100.0
# F1:  97.87234042553192
#
# Food
# Precision:  99.23518164435947
# Recall:  98.29545454545455
# F1:  98.76308277830638
#
# Medical
# Precision:  100.0
# Recall:  100.0
# F1:  100.0
#
# None
# Precision:  98.38709677419355
# Recall:  98.70550161812298
# F1:  98.54604200323104
#
# Water
# Precision:  100.0
# Recall:  98.01980198019803
# F1:  99.0
#
# Average F1:  98.83629304141387
